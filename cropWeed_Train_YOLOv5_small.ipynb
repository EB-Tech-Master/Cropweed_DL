# %% [markdown]
# # How to Train YOLOv5 on Custom Objects
#
# This tutorial is based on the [YOLOv5 repository](https://github.com/ultralytics/yolov5) by [Ultralytics](https://www.ultralytics.com/). This notebook shows training on **your own custom objects**. Many thanks to Ultralytics for putting this repository together - we hope that in combination with clean data management tools at Roboflow, this technologoy will become easily accessible to any developer wishing to use computer vision in their projects.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train YOLOv5](https://blog.roboflow.ai/how-to-train-yolov5-on-a-custom-dataset/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train YOLOv5 on your custom objects. We use a [public blood cell detection dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our detector we take the following steps:
#
# * Install YOLOv5 dependencies
# * Download custom YOLOv5 object detection data
# * Write our YOLOv5 Training configuration
# * Run YOLOv5 training
# * Evaluate YOLOv5 performance
# * Visualize YOLOv5 training data
# * Run YOLOv5 inference on test images
# * Export saved YOLOv5 weights for future inference

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Install Dependencies
#
# _(Remember to choose GPU in Runtime if not already selected. Runtime --> Change Runtime Type --> Hardware accelerator --> GPU)_

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13227, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 13227 (delta 15), reused 21 (delta 10), pack-reused 13198
# Receiving objects: 100% (13227/13227), 13.21 MiB | 17.82 MiB/s, done.
# Resolving deltas: 100% (9079/9079), done.
# /content/yolov5

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
# from utils.google_utils import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      |████████████████████████████████| 1.6 MB 42.5 MB/s
# Setup complete. Using torch 1.12.1+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat {'/content/drive/MyDrive/cropvsweed'}/data.yaml
# Out:
# train: /content/drive/MyDrive/cropvsweed/train/images
# val: /content/drive/MyDrive/cropvsweed/valid/images
# test: /content/drive/MyDrive/cropvsweed/test/images
#
# nc: 2
# names: ['crop','weed']

# %% [markdown]
# # Define Model Configuration and Architecture
#
# We will write a yaml script that defines the parameters for our model like the number of classes, anchors, and each layer.
#
# You do not need to edit these cells, but you may.

# %%
# define number of classes based on YAML
import yaml
with open('/content/drive/MyDrive/cropvsweed' + "/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
#this is the model configuration we will use for our tutorial 
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %% [markdown]
# # Train Custom YOLOv5 Detector
#
# ### Next, we'll fire off training!
#
#
# Here, we are able to pass a number of arguments:
# - **img:** define input image size
# - **batch:** determine batch size
# - **epochs:** define the number of training epochs. (Note: often, 3000+ are common here!)
# - **data:** set the path to our yaml file
# - **cfg:** specify our model configuration
# - **weights:** specify a custom path to weights. (Note: you can download weights from the Ultralytics Google Drive [folder](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J))
# - **name:** result names
# - **nosave:** only save the final checkpoint
# - **cache:** cache images for faster training

# %%
import shutil
shutil.rmtree('/content/yolov5/runs/val')

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 512 --batch 16 --epochs 100 --data {'/content/drive/MyDrive/cropvsweed'}/data.yaml --cfg ./models/custom_yolov5s.yaml --weights ''  --name yolov5s_cropweed  --cache
# Out:
# /content/yolov5
# train: weights=, cfg=./models/custom_yolov5s.yaml, data=/content/drive/MyDrive/cropvsweed/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_cropweed, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-183-gc98128f Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs in Weights & Biases
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 214 layers, 7025023 parameters, 7025023 gradients, 16.0 GFLOPs
#
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning '/content/drive/MyDrive/cropvsweed/train/labels.cache' images and labels... 780 found, 0 missing, 0 empty, 0 corrupt: 100% 780/780 [00:00<?, ?it/s]
# train: Caching images (0.6GB ram): 100% 780/780 [00:04<00:00, 170.06it/s]
# val: Scanning '/content/drive/MyDrive/cropvsweed/valid/labels.cache' images and labels... 260 found, 0 missing, 0 empty, 0 corrupt: 100% 260/260 [00:00<?, ?it/s]
# val: Caching images (0.2GB ram): 100% 260/260 [00:01<00:00, 139.62it/s]
#
# AutoAnchor: 3.80 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/yolov5s_cropweed/labels.jpg...
# Image sizes 512 train, 512 val
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_cropweed
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/99      2.38G     0.1014    0.02891    0.02749         43        512: 100% 49/49 [00:12<00:00,  3.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:03<00:00,  2.99it/s]
#                    all        260        449    0.00115      0.244   0.000872   0.000316
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      2.98G    0.09261    0.02997    0.02698         31        512: 100% 49/49 [00:11<00:00,  4.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  3.14it/s]
#                    all        260        449    0.00116      0.224    0.00154   0.000442
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      2.98G    0.08725    0.03053    0.02634         40        512: 100% 49/49 [00:09<00:00,  5.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  4.36it/s]
#                    all        260        449       0.58     0.0824      0.033     0.0103
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      2.98G    0.08592    0.03026    0.02559         31        512: 100% 49/49 [00:09<00:00,  5.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  3.82it/s]
#                    all        260        449      0.627     0.0609     0.0298    0.00934
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      2.98G    0.08113    0.02907    0.02499         45        512: 100% 49/49 [00:09<00:00,  5.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  3.56it/s]
#                    all        260        449     0.0889      0.116     0.0651     0.0171
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      2.98G    0.08039    0.03048    0.02385         32        512: 100% 49/49 [00:09<00:00,  5.03it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  4.22it/s]
#                    all        260        449      0.532      0.215     0.0334    0.00813
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      2.98G    0.07721    0.03055    0.02307         45        512: 100% 49/49 [00:11<00:00,  4.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.50it/s]
#                    all        260        449      0.146      0.199     0.0693     0.0168
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      2.98G    0.07332    0.03052    0.02228         36        512: 100% 49/49 [00:09<00:00,  5.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  4.36it/s]
#                    all        260        449      0.149      0.298      0.108     0.0304
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99      2.98G    0.06967    0.03049    0.02169         34        512: 100% 49/49 [00:09<00:00,  5.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  3.67it/s]
#                    all        260        449     0.0911      0.234      0.036    0.00791
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99      2.98G    0.06625    0.02893    0.01995         39        512: 100% 49/49 [00:09<00:00,  5.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  4.21it/s]
#                    all        260        449      0.116      0.272     0.0846     0.0213
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99      2.98G    0.06701     0.0298    0.01776         44        512: 100% 49/49 [00:09<00:00,  5.13it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  3.74it/s]
#                    all        260        449      0.162      0.329       0.11     0.0316
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/99      2.98G    0.06413    0.02844    0.01788         25        512: 100% 49/49 [00:09<00:00,  5.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  4.03it/s]
#                    all        260        449      0.321      0.278      0.204     0.0508
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/99      2.98G    0.06336    0.02935    0.01731         36        512: 100% 49/49 [00:09<00:00,  5.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  4
0.477
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       88/99      2.98G    0.03763    0.02246   0.004107         43        512: 100% 49/49 [00:09<00:00,  5.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.74it/s]
#                    all        260        449      0.787      0.762      0.828      0.478
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       89/99      2.98G    0.03858    0.02307   0.003771         48        512: 100% 49/49 [00:09<00:00,  5.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.53it/s]
#                    all        260        449      0.755      0.744        0.8      0.438
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       90/99      2.98G    0.03672    0.02279   0.004035         34        512: 100% 49/49 [00:09<00:00,  5.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.66it/s]
#                    all        260        449      0.779      0.763      0.818      0.479
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       91/99      2.98G    0.03777    0.02181   0.004295         37        512: 100% 49/49 [00:09<00:00,  5.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.60it/s]
#                    all        260        449      0.789      0.745      0.813      0.463
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       92/99      2.98G    0.03784     0.0229   0.003915         38        512: 100% 49/49 [00:09<00:00,  5.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.52it/s]
#                    all        260        449      0.795      0.738      0.818      0.472
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       93/99      2.98G    0.03803    0.02298    0.00444         34        512: 100% 49/49 [00:09<00:00,  5.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.57it/s]
#                    all        260        449      0.765      0.765      0.805      0.473
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       94/99      2.98G    0.03735    0.02275   0.004192         52        512: 100% 49/49 [00:09<00:00,  5.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.57it/s]
#                    all        260        449      0.777      0.751      0.831      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       95/99      2.98G    0.03823    0.02372   0.003837         35        512: 100% 49/49 [00:09<00:00,  5.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.52it/s]
#                    all        260        449      0.784      0.767      0.825       0.48
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       96/99      2.98G     0.0369    0.02207   0.003953         31        512: 100% 49/49 [00:09<00:00,  5.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  4.50it/s]
#                    all        260        449      0.761      0.759      0.814      0.484
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       97/99      2.98G    0.03628    0.02175   0.003866         40        512: 100% 49/49 [00:09<00:00,  5.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:02<00:00,  4.01it/s]
#                    all        260        449      0.746      0.785      0.821       0.48
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       98/99      2.98G     0.0365    0.02282    0.00348         48        512: 100% 49/49 [00:10<00:00,  4.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.51it/s]
#                    all        260        449      0.747      0.782      0.811      0.468
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       99/99      2.98G    0.03732    0.02347   0.003903         35        512: 100% 49/49 [00:09<00:00,  5.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:01<00:00,  4.56it/s]
#                    all        260        449      0.762      0.765      0.814      0.481
#
# 100 epochs completed in 0.340 hours.
# Optimizer stripped from runs/train/yolov5s_cropweed/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/yolov5s_cropweed/weights/best.pt, 14.4MB
#
# Validating runs/train/yolov5s_cropweed/weights/best.pt...
# Fusing layers...
# custom_YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:03<00:00,  2.48it/s]
#                    all        260        449       0.76      0.759      0.813      0.484
#                   crop        260        279        0.7       0.76      0.779       0.47
#                   weed        260        170      0.821      0.759      0.848      0.499
# Results saved to runs/train/yolov5s_cropweed
# CPU times: user 18 s, sys: 3.9 s, total: 21.9 s
# Wall time: 21min 1s

# %% [markdown]
# # Evaluate Custom YOLOv5 Detector Performance

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a logfile defined above with the **--name** flag when we train. In our case, we named this `yolov5s_results`. (If given no name, it defaults to `results.txt`.) The results file is plotted as a png after training completes.
#
# Note from Glenn: Partially completed `results.txt` files can be plotted with `from utils.utils import plot_results; plot_results()`.

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_cropweed/results.png', width=1000)  # view results.png

# %% [markdown]
# ### Curious? Visualize Our Training Data with Labels
#
# After training starts, view `train*.jpg` images to see training images, labels and augmentation effects.
#
# Note a mosaic dataloader is used for training (shown below), a new dataloading concept developed by Glenn Jocher and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
# first, display our ground truth data
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_cropweed/val_batch2_labels.jpg', width=900)
# Out:
# GROUND TRUTH TRAINING DATA:

# %%
# print out an augmented training example
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_cropweed/train_batch0.jpg', width=1000)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %% [markdown]
# # Run Evaluation With Trained Weights

# %%
# %cd /content/yolov5/
# !python val.py  --batch 16 --data {'/content/drive/MyDrive/cropvsweed'}/data.yaml --weights runs/train/yolov5s_cropweed/weights/best.pt --task test --name 'Testing' --augment --verbose --verbose
# Out:
# /content/yolov5
# val: data=/content/drive/MyDrive/cropvsweed/data.yaml, weights=['runs/train/yolov5s_cropweed/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=True, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=Testing, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-183-gc98128f Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# custom_YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning '/content/drive/MyDrive/cropvsweed/test/labels.cache' images and labels... 260 found, 0 missing, 0 empty, 0 corrupt: 100% 260/260 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 17/17 [00:08<00:00,  1.93it/s]
#                    all        260        419      0.766      0.715       0.77      0.444
#                   crop        260        229      0.778      0.703      0.771      0.485
#                   weed        260        190      0.754      0.726      0.769      0.403
# Speed: 0.6ms pre-process, 15.2ms inference, 3.0ms NMS per image at shape (16, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/Testing2/best_predictions.json...
# loading annotations into memory...
# pycocotools unable to run: [Errno 2] No such file or directory: '../coco/annotations/instances_val2017.json'
# Results saved to runs/val/Testing2

# %%
Image(filename='/content/yolov5/runs/val/Testing/P_curve.png', width=1000)

# %%
Image(filename='/content/yolov5/runs/val/Testing/R_curve.png', width=1000)

# %%
Image(filename='/content/yolov5/runs/val/Testing/PR_curve.png', width=1000)

# %%
Image(filename='/content/yolov5/runs/val/Testing/F1_curve.png', width=1000)

# %%
Image(filename='/content/yolov5/runs/val/Testing/confusion_matrix.png', width=1000)

# %% [markdown]
# #Run Inference  With Trained Weights
# Run inference with a pretrained checkpoint on contents of `test/images` folder downloaded from Roboflow.

# %%
# trained weights are saved by default in our weights folder
# %ls runs/
# Out:
# train/

# %%
# %ls runs/train/yolov5s_cropweed/weights
# Out:
# best.pt  last.pt

# %%
# when we ran this, we saw .007 second inference time. That is 140 FPS on a TESLA P100!
# use the best weights!
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_cropweed/weights/best.pt --img 512 --conf 0.8 --source /content/drive/MyDrive/cropvsweed/test/images
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5m_cropweed/weights/best.pt'], source=/content/drive/MyDrive/cropvsweed/test/images, data=data/coco128.yaml, imgsz=[512, 512], conf_thres=0.8, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-278-g1ab23fc Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# custom_YOLOv5m summary: 232 layers, 7249215 parameters, 0 gradients, 16.7 GFLOPs
# image 1/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1009.jpeg: 512x512 Done. (0.013s)
# image 2/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1017.jpeg: 512x512 Done. (0.013s)
# image 3/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1018.jpeg: 512x512 Done. (0.057s)
# image 4/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1020.jpeg: 512x512 Done. (0.014s)
# image 5/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1024.jpeg: 512x512 1 weed, Done. (0.013s)
# image 6/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1026.jpeg: 512x512 1 crop, Done. (0.013s)
# image 7/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1028.jpeg: 512x512 Done. (0.013s)
# image 8/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1041.jpeg: 512x512 1 crop, Done. (0.013s)
# image 9/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1053.jpeg: 512x512 Done. (0.013s)
# image 10/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_106.jpeg: 512x512 Done. (0.013s)
# image 11/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1068.jpeg: 512x512 Done. (0.013s)
# image 12/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1079.jpeg: 512x512 Done. (0.017s)
# image 13/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1082.jpeg: 512x512 Done. (0.015s)
# image 14/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1083.jpeg: 512x512 1 crop, Done. (0.013s)
# image 15/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1094.jpeg: 512x512 Done. (0.016s)
# image 16/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1095.jpeg: 512x512 Done. (0.013s)
# image 17/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_110.jpeg: 512x512 1 crop, Done. (0.013s)
# image 18/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1114.jpeg: 512x512 Done. (0.013s)
# image 19/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1119.jpeg: 512x512 1 crop, Done. (0.013s)
# image 20/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1123.jpeg: 512x512 1 crop, Done. (0.013s)
# image 21/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1129.jpeg: 512x512 Done. (0.013s)
# image 22/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_113.jpeg: 512x512 Done. (0.014s)
# image 23/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1130.jpeg: 512x512 1 weed, Done. (0.012s)
# image 24/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_114.jpeg: 512x512 1 crop, Done. (0.013s)
# image 25/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1140.jpeg: 512x512 Done. (0.012s)
# image 26/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1146.jpeg: 512x512 Done. (0.017s)
# image 27/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1166.jpeg: 512x512 Done. (0.013s)
# image 28/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1168.jpeg: 512x512 1 weed, Done. (0.013s)
# image 29/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1171.jpeg: 512x512 1 crop, Done. (0.012s)
# image 30/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1173.jpeg: 512x512 Done. (0.012s)
# image 31/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1174.jpeg: 512x512 1 crop, Done. (0.012s)
# image 32/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1177.jpeg: 512x512 1 crop, Done. (0.012s)
# image 33/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1192.jpeg: 512x512 Done. (0.013s)
# image 34/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1193.jpeg: 512x512 Done. (0.013s)
# image 35/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1198.jpeg: 512x512 Done. (0.013s)
# image 36/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_
260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1961.jpeg: 512x512 Done. (0.015s)
# image 133/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1966.jpeg: 512x512 Done. (0.014s)
# image 134/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1985.jpeg: 512x512 Done. (0.013s)
# image 135/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1988.jpeg: 512x512 Done. (0.013s)
# image 136/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1990.jpeg: 512x512 1 crop, Done. (0.013s)
# image 137/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1992.jpeg: 512x512 1 weed, Done. (0.012s)
# image 138/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_1993.jpeg: 512x512 Done. (0.013s)
# image 139/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2001.jpeg: 512x512 Done. (0.013s)
# image 140/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_203.jpeg: 512x512 1 weed, Done. (0.013s)
# image 141/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2034.jpeg: 512x512 1 crop, Done. (0.013s)
# image 142/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2040.jpeg: 512x512 1 weed, Done. (0.013s)
# image 143/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2077.jpeg: 512x512 Done. (0.014s)
# image 144/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2082.jpeg: 512x512 Done. (0.013s)
# image 145/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2136.jpeg: 512x512 Done. (0.013s)
# image 146/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2144.jpeg: 512x512 Done. (0.013s)
# image 147/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2158.jpeg: 512x512 1 weed, Done. (0.017s)
# image 148/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2204.jpeg: 512x512 Done. (0.013s)
# image 149/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_221.jpeg: 512x512 Done. (0.013s)
# image 150/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2228.jpeg: 512x512 Done. (0.012s)
# image 151/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_223.jpeg: 512x512 Done. (0.013s)
# image 152/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_224.jpeg: 512x512 Done. (0.012s)
# image 153/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2244.jpeg: 512x512 Done. (0.013s)
# image 154/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2320.jpeg: 512x512 1 weed, Done. (0.012s)
# image 155/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2326.jpeg: 512x512 Done. (0.017s)
# image 156/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2345.jpeg: 512x512 1 weed, Done. (0.012s)
# image 157/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_237.jpeg: 512x512 1 crop, Done. (0.012s)
# image 158/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2370.jpeg: 512x512 Done. (0.012s)
# image 159/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_2385.jpeg: 512x512 Done. (0.012s)
# image 160/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_248.jpeg: 512x512 Done. (0.012s)
# image 161/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_249.jpeg: 512x512 1 crop, Done. (0.013s)
# image 162/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_270.jpeg: 512x512 Done. (0.014s)
# image 163/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_272.jpeg: 512x512 1 crop, Done. (0.015s)
# image 164/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_277.jpeg: 512x512 1 weed, Done. (0.013s)
# image 165/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_299.jpeg: 512x512 1 weed, Done. (0.013s)
# image 166/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_3.jpeg: 512x512 1 crop, Done. (0.015s)
# image 167/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_301.jpeg: 512x512 1 crop, Done. (0.013s)
# image 168/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_318.jpeg: 512x512 2 crops, Done. (0.013s)
# image 169/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_326.jpeg: 512x512 1 crop, Done. (0.017s)
# image 170/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_333.jpeg: 512x512 1 crop, Done. (0.012s)
# image 171/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_347.jpeg: 512x512 Done. (0.012s)
# image 172/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_352.jpeg: 512x512 1 weed, Done. (0.015s)
# image 173/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_357.jpeg: 512x512 Done. (0.014s)
# image 174/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_372.jpeg: 512x512 1 crop, Done. (0.012s)
# image 175/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_376.jpeg: 512x512 Done. (0.013s)
# image 176/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_377.jpeg: 512x512 1 weed, Done. (0.012s)
# image 177/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_39.jpeg: 512x512 1 weed, Done. (0.012s)
# image 178/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_395.jpeg: 512x512 Done. (0.012s)
# image 179/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_401.jpeg: 512x512 Done. (0.013s)
# image 180/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_402.jpeg: 512x512 1 crop, Done. (0.013s)
# image 181/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_417.jpeg: 512x512 Done. (0.012s)
# image 182/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_437.jpeg: 512x512 1 crop, Done. (0.013s)
# image 183/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_452.jpeg: 512x512 Done. (0.012s)
# image 184/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_456.jpeg: 512x512 1 crop, Done. (0.016s)
# image 185/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_462.jpeg: 512x512 Done. (0.014s)
# image 186/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_466.jpeg: 512x512 1 weed, Done. (0.013s)
# image 187/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_484.jpeg: 512x512 1 crop, Done. (0.013s)
# image 188/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_487.jpeg: 512x512 Done. (0.012s)
# image 189/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_491.jpeg: 512x512 Done. (0.012s)
# image 190/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_495.jpeg: 512x512 2 crops, Done. (0.012s)
# image 191/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_526.jpeg: 512x512 Done. (0.012s)
# image 192/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_543.jpeg: 512x512 1 weed, Done. (0.015s)
# image 193/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_544.jpeg: 512x512 Done. (0.012s)
# image 194/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_550.jpeg: 512x512 Done. (0.012s)
# image 195/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_551.jpeg: 512x512 1 crop, Done. (0.012s)
# image 196/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_561.jpeg: 512x512 1 crop, Done. (0.012s)
# image 197/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_566.jpeg: 512x512 Done. (0.012s)
# image 198/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_567.jpeg: 512x512 Done. (0.012s)
# image 199/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_57.jpeg: 512x512 1 crop, Done. (0.012s)
# image 200/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_583.jpeg: 512x512 1 crop, Done. (0.017s)
# image 201/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_584.jpeg: 512x512 1 weed, Done. (0.012s)
# image 202/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_596.jpeg: 512x512 1 crop, Done. (0.012s)
# image 203/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_6.jpeg: 512x512 Done. (0.015s)
# image 204/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_60.jpeg: 512x512 Done. (0.012s)
# image 205/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_600.jpeg: 512x512 Done. (0.013s)
# image 206/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_601.jpeg: 512x512 1 crop, Done. (0.012s)
# image 207/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_603.jpeg: 512x512 Done. (0.013s)
# image 208/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_607.jpeg: 512x512 1 weed, Done. (0.012s)
# image 209/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_614.jpeg: 512x512 Done. (0.012s)
# image 210/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_618.jpeg: 512x512 Done. (0.013s)
# image 211/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_626.jpeg: 512x512 Done. (0.015s)
# image 212/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_629.jpeg: 512x512 1 weed, Done. (0.012s)
# image 213/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_630.jpeg: 512x512 Done. (0.012s)
# image 214/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_631.jpeg: 512x512 1 crop, Done. (0.012s)
# image 215/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_641.jpeg: 512x512 1 crop, Done. (0.012s)
# image 216/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_654.jpeg: 512x512 Done. (0.012s)
# image 217/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_657.jpeg: 512x512 Done. (0.012s)
# image 218/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_665.jpeg: 512x512 1 crop, Done. (0.012s)
# image 219/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_667.jpeg: 512x512 Done. (0.012s)
# image 220/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_683.jpeg: 512x512 Done. (0.013s)
# image 221/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_714.jpeg: 512x512 Done. (0.012s)
# image 222/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_718.jpeg: 512x512 1 crop, Done. (0.012s)
# image 223/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_725.jpeg: 512x512 Done. (0.013s)
# image 224/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_741.jpeg: 512x512 Done. (0.012s)
# image 225/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_744.jpeg: 512x512 1 crop, Done. (0.012s)
# image 226/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_752.jpeg: 512x512 1 weed, Done. (0.012s)
# image 227/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_757.jpeg: 512x512 Done. (0.012s)
# image 228/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_76.jpeg: 512x512 1 weed, Done. (0.012s)
# image 229/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_773.jpeg: 512x512 1 crop, Done. (0.012s)
# image 230/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_780.jpeg: 512x512 Done. (0.012s)
# image 231/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_784.jpeg: 512x512 Done. (0.012s)
# image 232/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_787.jpeg: 512x512 1 crop, Done. (0.012s)
# image 233/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_789.jpeg: 512x512 1 crop, Done. (0.012s)
# image 234/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_808.jpeg: 512x512 Done. (0.013s)
# image 235/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_81.jpeg: 512x512 1 crop, Done. (0.012s)
# image 236/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_815.jpeg: 512x512 Done. (0.012s)
# image 237/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_82.jpeg: 512x512 Done. (0.012s)
# image 238/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_823.jpeg: 512x512 1 weed, Done. (0.014s)
# image 239/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_830.jpeg: 512x512 Done. (0.019s)
# image 240/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_838.jpeg: 512x512 1 crop, Done. (0.013s)
# image 241/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_839.jpeg: 512x512 1 crop, Done. (0.013s)
# image 242/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_84.jpeg: 512x512 Done. (0.013s)
# image 243/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_840.jpeg: 512x512 1 crop, Done. (0.013s)
# image 244/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_864.jpeg: 512x512 1 crop, Done. (0.014s)
# image 245/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_866.jpeg: 512x512 1 crop, Done. (0.014s)
# image 246/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_871.jpeg: 512x512 Done. (0.012s)
# image 247/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_879.jpeg: 512x512 Done. (0.012s)
# image 248/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_882.jpeg: 512x512 Done. (0.012s)
# image 249/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_899.jpeg: 512x512 Done. (0.013s)
# image 250/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_909.jpeg: 512x512 1 weed, Done. (0.012s)
# image 251/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_911.jpeg: 512x512 1 weed, Done. (0.012s)
# image 252/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_915.jpeg: 512x512 Done. (0.013s)
# image 253/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_920.jpeg: 512x512 Done. (0.013s)
# image 254/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_934.jpeg: 512x512 Done. (0.012s)
# image 255/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_935.jpeg: 512x512 1 crop, Done. (0.013s)
# image 256/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_941.jpeg: 512x512 Done. (0.013s)
# image 257/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_954.jpeg: 512x512 Done. (0.016s)
# image 258/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_975.jpeg: 512x512 1 weed, Done. (0.012s)
# image 259/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_980.jpeg: 512x512 1 crop, Done. (0.013s)
# image 260/260 /content/drive/MyDrive/cropvsweed/test/images/agri_0_991.jpeg: 512x512 Done. (0.013s)
# Speed: 0.4ms pre-process, 13.3ms inference, 0.6ms NMS per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/exp

# %%
#display inference on ALL test images
#this looks much better with longer training above

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpeg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %% [markdown]
# # Export Trained Weights for Future Inference
#
# Now that you have trained your custom detector, you can export the trained weights you have made here for inference on your device elsewhere

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/yolov5/runs/train/yolov5s_cropweed/weights/best.pt /content/drive/MyDrive

# %% [markdown]
# ## Congrats!
#
# Hope you enjoyed this!
#
# --Team [Roboflow](https://roboflow.ai)

# %%
# %cd /content/yolov5/
# !python detect.py --source /content/drive/MyDrive/cropvsweed/test/images/agri_0_131.jpeg --weights /content/yolov5/runs/train/yolov5s_cropweed/weights/best.pt
# Out:
# /content/yolov5
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/drive/MyDrive/cropvsweed/test/images/agri_0_131.jpeg', update=False, view_img=False, weights=['/content/yolov5/runs/train/yolov5m_cropweed/weights/best.pt'])
# YOLOv5 v4.0-126-g886f1c0 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 232 layers, 7249215 parameters, 0 gradients, 16.7 GFLOPS
# image 1/1 /content/drive/MyDrive/cropvsweed/test/images/agri_0_131.jpeg: 640x640 2 crops, Done. (0.020s)
# Results saved to runs/detect/exp3
# Done. (0.041s)

# %%
import torch
import numpy as np
import cv2
from time import time
import matplotlib.pyplot as plt


class MugDetection:
    """
    Class implements Yolo5 model to make inferences on a youtube video using Opencv2.
    """

    def __init__(self, capture_index, model_name):
        """
        Initializes the class with youtube url and output file.
        :param url: Has to be as youtube URL,on which prediction is made.
        :param out_file: A valid output file name.
        """
        self.capture_index = capture_index
        self.model = self.load_model(model_name)
        self.classes = self.model.names
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        print("Using Device: ", self.device)

    def load_model(self, model_name):
        """
        Loads Yolo5 model from pytorch hub.
        :return: Trained Pytorch model.
        """
        if model_name:
            model = torch.hub.load('ultralytics/yolov5', 'custom', path=model_name, force_reload=True)
        else:
            model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
        return model

    def score_frame(self, frame):
        """
        Takes a single frame as input, and scores the frame using yolo5 model.
        :param frame: input frame in numpy/list/tuple format.
        :return: Labels and Coordinates of objects detected by model in the frame.
        """
        self.model.to(self.device)
        frame = [frame]
        results = self.model(frame)
        labels, cord = results.xyxyn[0][:, -1], results.xyxyn[0][:, :-1]
        return labels, cord

    def class_to_label(self, x):
        """
        For a given label value, return corresponding string label.
        :param x: numeric label
        :return: corresponding string label
        """
        return self.classes[int(x)]

    def plot_boxes(self, results, frame):
        """
        Takes a frame and its results as input, and plots the bounding boxes and label on to the frame.
        :param results: contains labels and coordinates predicted by model on the given frame.
        :param frame: Frame which has been scored.
        :return: Frame with bounding boxes and labels ploted on it.
        """
        labels, cord = results
        n = len(labels)
        x_shape, y_shape = frame.shape[1], frame.shape[0]
        for i in range(n):
            row = cord[i]
            if row[4] >= 0.3:
                x1, y1, x2, y2 = int(row[0]*x_shape), int(row[1]*y_shape), int(row[2]*x_shape), int(row[3]*y_shape)
                bgr = (0, 255, 0) if self.class_to_label(labels[i])=="crop" else (255, 0, 00)
                cv2.rectangle(frame, (x1, y1), (x2, y2), bgr, 4)
                cv2.putText(frame, self.class_to_label(labels[i]), (x1, y1), cv2.FONT_HERSHEY_SIMPLEX, 1, bgr, 2)

        return frame

    def __call__(self):
        """
        This function is called when class is executed, it runs the loop to read the video frame by frame,
        and write the output into a new file.
        :return: void
        """
        img = cv2.imread('/content/drive/MyDrive/cropvsweed/test/images/agri_0_131.jpeg')
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        results = self.score_frame(img)
        frame = self.plot_boxes(results, img)
        plt.imshow(frame)
        plt.show()   
# Create a new object and execute.
detector = MugDetection(capture_index=0, model_name='/content/drive/MyDrive/best.pt')
detector()
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (6.0)
#
# requirements: 1 package updated per /content/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v6.1-278-g1ab23fc Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# custom_YOLOv5m summary: 232 layers, 7249215 parameters, 0 gradients, 16.7 GFLOPs
# Adding AutoShape...
# Using Device:  cuda

# %%
# %cd /content/yolov5/
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/yolov5/runs/train/yolov5s_cropweed/weights/best.pt', force_reload=True)
# Out:
# /content/yolov5
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (6.0)
#
# requirements: 1 package updated per /content/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v6.1-278-g1ab23fc Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# custom_YOLOv5m summary: 232 layers, 7249215 parameters, 0 gradients, 16.7 GFLOPs
# Adding AutoShape...

# %%
import cv2
import torch
from PIL import Image
# %matplotlib inline

# Model


# Images
img1 = Image.open('/content/drive/MyDrive/cropvsweed/test/images/agri_0_131.jpeg')  # PIL image


# Inference
results = model(img1)  # includes NMS

plt.imshow(np.squeeze(results.render()))
plt.show()
